# %%
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import statistics as stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9456\2488345127.py in <module>
#       2 import numpy as np
#       3 from datetime import datetime
# ----> 4 import seaborn as sns
#       5 import matplotlib.pyplot as plt
#       6 import statistics as stats
#
# c:\Users\HOME\anaconda3\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# c:\Users\HOME\anaconda3\lib\site-packages\seaborn\rcmod.py in <module>
#       3 import functools
#       4 from distutils.version import LooseVersion
# ----> 5 import matplotlib as mpl
#       6 from cycler import cycler
#       7 from . import palettes
#
# c:\Users\HOME\anaconda3\lib\site-packages\matplotlib\__init__.py in <module>
#     885 # triggering resolution of _auto_backend_sentinel.
#     886 rcParamsDefault = _rc_params_in_file(
# --> 887     cbook._get_data_path("matplotlibrc"),
#     888     # Strip leading comment.
#     889     transform=lambda line: line[1:] if line.startswith("#") else line,
#
# c:\Users\HOME\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _get_data_path(*args)
#     557     ``*args`` specify a path relative to the base data path.
#     558     """
# --> 559     return Path(matplotlib.get_data_path(), *args)
#     560
#     561
#
# AttributeError: module 'matplotlib' has no attribute 'get_data_path'

# %%
df=pd.read_csv('finalTrain.csv')

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
# Calculate Distance between resturant and location
R =6371
def deg_to_rad(degrees):
    return degrees * (np.pi/180)

# %%
def distcalculate(lat1, lon1, lat2, lon2):
    d_lat = deg_to_rad(lat2-lat1)
    d_lon = deg_to_rad(lon2-lon1)
    a = np.sin(d_lat/2)**2 + np.cos(deg_to_rad(lat1)) * np.cos(deg_to_rad(lat2)) * np.sin(d_lon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

# %%
df['distance'] = np.nan

# %%
for i in range(len(df)):
    df.loc[i, 'distance'] = distcalculate(df.loc[i, 'Restaurant_latitude'], 
                                        df.loc[i, 'Restaurant_longitude'], 
                                        df.loc[i, 'Delivery_location_latitude'], 
                                        df.loc[i, 'Delivery_location_longitude'])

# %%
df=df.drop(labels=['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude'], axis=1)

# %%
df['Day']=df['Order_Date'].str.split('-').str[0]
df['Month']=df['Order_Date'].str.split('-').str[1].str.split('-').str[0]
df['Year']=df['Order_Date'].str.split('-').str[2]

# %%
df['Day']= df['Day'].astype('int')
df['Month']= df['Month'].astype('int')
df['Year']= df['Year'].astype('int')

# %%
df=df.drop(labels=['ID','Delivery_person_ID','Order_Date','Time_Orderd','Time_Order_picked'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_Age      43730 non-null  float64
#  1   Delivery_person_Ratings  43676 non-null  float64
#  2   Weather_conditions       44968 non-null  object
#  3   Road_traffic_density     44983 non-null  object
#  4   Vehicle_condition        45584 non-null  int64
#  5   Type_of_order            45584 non-null  object
#  6   Type_of_vehicle          45584 non-null  object
#  7   multiple_deliveries      44591 non-null  float64
#  8   Festival                 45356 non-null  object
#  9   City                     44384 non-null  object
#  10  Time_taken (min)         45584 non-null  int64
#  11  distance                 45584 non-null  float64
#  12  Day                      45584 non-null  int32
#  13  Month                    45584 non-null  int32
#  14  Year                     45584 non-null  int32
# dtypes: float64(4), int32(3), int64(2), object(6)
# memory usage: 4.7+ MB

# %%
df.to_csv('final_cleaned_train_V2.csv')

# %%
df.head(2)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
# 1                 21.0                      4.7             Stormy
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
# 1                 High                  1          Meal      motorcycle
#
#    multiple_deliveries Festival           City  Time_taken (min)   distance  \
# 0                  3.0       No  Metropolitian                46  10.280582
# 1                  1.0       No  Metropolitian                23   6.242319
#
#    Day  Month  Year
# 0   12      2  2022
# 1   13      2  2022

# %%
df_new = df.copy()

# %%
target ='Time_taken (min)'
df_new_target = [target]

# %%
target_Delv_Time_Name = 'Time_taken (min)'
#Drop if any unwanted columns like ID, Target etc
drop_columns = [target_Delv_Time_Name]
df_new = df.drop(columns=drop_columns, axis=1)

# %%
df_new.head(1)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
#
#    multiple_deliveries Festival           City   distance  Day  Month  Year
# 0                  3.0       No  Metropolitian  10.280582   12      2  2022

# %%
df_new['Time_taken (min)'] = np.nan

# %%
df_new['Time_taken (min)'] = df['Time_taken (min)']

# %%
df_new.head(1)
# Out:
#    Delivery_person_Age  Delivery_person_Ratings Weather_conditions  \
# 0                 36.0                      4.2                Fog
#
#   Road_traffic_density  Vehicle_condition Type_of_order Type_of_vehicle  \
# 0                  Jam                  2         Snack      motorcycle
#
#    multiple_deliveries Festival           City   distance  Day  Month  Year  \
# 0                  3.0       No  Metropolitian  10.280582   12      2  2022
#
#    Time_taken (min)
# 0                46

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Delivery_person_Age      43730 non-null  float64
#  1   Delivery_person_Ratings  43676 non-null  float64
#  2   Weather_conditions       44968 non-null  object
#  3   Road_traffic_density     44983 non-null  object
#  4   Vehicle_condition        45584 non-null  int64
#  5   Type_of_order            45584 non-null  object
#  6   Type_of_vehicle          45584 non-null  object
#  7   multiple_deliveries      44591 non-null  float64
#  8   Festival                 45356 non-null  object
#  9   City                     44384 non-null  object
#  10  distance                 45584 non-null  float64
#  11  Day                      45584 non-null  int32
#  12  Month                    45584 non-null  int32
#  13  Year                     45584 non-null  int32
#  14  Time_taken (min)         45584 non-null  int64
# dtypes: float64(4), int32(3), int64(2), object(6)
# memory usage: 4.7+ MB

# %%
df_new.to_csv('final_cleaned_train_V3.csv')

# %%
df_new.iloc[:,1:]
# Out:
#        Delivery_person_Ratings Weather_conditions Road_traffic_density  \
# 0                          4.2                Fog                  Jam
# 1                          4.7             Stormy                 High
# 2                          4.7         Sandstorms               Medium
# 3                          4.3         Sandstorms                  Low
# 4                          4.7                Fog                  Jam
# ...                        ...                ...                  ...
# 45579                      4.8              Windy                 High
# 45580                      4.6              Windy                  Jam
# 45581                      4.9             Cloudy                  Low
# 45582                      4.7             Cloudy                 High
# 45583                      4.9                Fog               Medium
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 0                      2         Snack      motorcycle                  3.0
# 1                      1          Meal      motorcycle                  1.0
# 2                      1        Drinks         scooter                  1.0
# 3                      0        Buffet      motorcycle                  0.0
# 4                      1         Snack         scooter                  1.0
# ...                  ...           ...             ...                  ...
# 45579                  1          Meal      motorcycle                  0.0
# 45580                  0        Buffet      motorcycle                  1.0
# 45581                  1        Drinks         scooter                  0.0
# 45582                  0         Snack      motorcycle                  1.0
# 45583                  2         Snack         scooter                  1.0
#
#       Festival           City   distance  Day  Month  Year  Time_taken (min)
# 0           No  Metropolitian  10.280582   12      2  2022                46
# 1           No  Metropolitian   6.242319   13      2  2022                23
# 2           No  Metropolitian  13.787860    4      3  2022                21
# 3           No  Metropolitian   2.930258   13      2  2022                20
# 4           No  Metropolitian  19.396618   14      2  2022                41
# ...        ...            ...        ...  ...    ...   ...               ...
# 45579       No  Metropolitian   1.489846   24      3  2022                32
# 45580       No  Metropolitian  11.007735   16      2  2022                36
# 45581       No  Metropolitian   4.657195   11      3  2022                16
# 45582       No  Metropolitian   6.232393    7      3  2022                26
# 45583       No  Metropolitian  12.074396    2      3  2022                36
#
# [45584 rows x 14 columns]
